# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries:

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import api_key, api_secret

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='food' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[40.261455,-76.882553] # Downtown Harrisburg, PA - Capital of Pennsylvania
# Setup a search distance
distance='20'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=15


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 15:18:48 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/kangdede78/sta…',
#      'expanded_url': 'https://twitter.com/kangdede78/status/836828966539440130',
#      'indices': [78, 101],
#      'url': 'https://t.co/DTMUyleVnL'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836958908178542592,
#   'id_str': '836958908178542592',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'in',
#   'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 06:42:27 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/836828966539440130',
#       'indices': [110, 133],
#       'url': 'https://t.co/SRJXMSE1B7'}],
#     'user_mentions': []},
#    'favorite_count': 130,
#    'favorited': False,
#    'geo': None,
#    'id': 836828966539440130,
#    'id_str': '836828966539440130',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'in',
#    'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 150,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'Kemaren ada yg menolak Salaman dgn Ahok krn ktrnya penista agama, hari ini Tuhan menunjukan kuasaNYA melalui… https://t.co/SRJXMSE1B7',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Jan 09 12:08:41 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Kebenaran akan menemukan jalannya Sendiri.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 162,
#     'follow_request_sent': None,
#     'followers_count': 41653,
#     'following': None,
#     'friends_count': 1160,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 235931838,
#     'id_str': '235931838',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 78,
#     'location': 'Jakarta Pusat, DKI Jakarta',
#     'name': 'Dede Budhiyarto',
#     'notifications': None,
#     'profile_background_color': 'DD2E44',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/695429040329486338/KIqLgHiE.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/695429040329486338/KIqLgHiE.jpg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/235931838/1480770013',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/836847878450589698/RAWtqybt_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/836847878450589698/RAWtqybt_normal.jpg',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'kangdede78',
#     'statuses_count': 181841,
#     'time_zone': 'Hawaii',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -36000,
#     'verified': False}},
#   'quoted_status_id': 836828966539440130,
#   'quoted_status_id_str': '836828966539440130',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'text': 'Yg menentukan penista agama atau bukan adalah Hakim, bukan lawan politik Ahok https://t.co/DTMUyleVnL',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Dec 24 12:08:36 +0000 2009',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Do the right things !',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1961,
#    'follow_request_sent': None,
#    'followers_count': 350,
#    'following': None,
#    'friends_count': 412,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 99091448,
#    'id_str': '99091448',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'Australia',
#    'name': 'ichiwara',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/99091448/1486824757',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/828418886806630401/WTpLzLBO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/828418886806630401/WTpLzLBO_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ichiwara',
#    'statuses_count': 9661,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 15:18:13 +0000 2017',
#   'entities': {'hashtags': [{'indices': [0, 10], 'text': 'PojokSatu'},
#     {'indices': [57, 62], 'text': 'Ahok'},
#     {'indices': [98, 107], 'text': 'nasional'}],
#    'symbols': [],
#    'urls': [{'display_url': 'goo.gl/fb/K0YR4C',
#      'expanded_url': 'https://goo.gl/fb/K0YR4C',
#      'indices': [74, 97],
#      'url': 'https://t.co/yruLifFRYW'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836958762594406400,
#   'id_str': '836958762594406400',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'in',
#   'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.google.com/" rel="nofollow">Google</a>',
#   'text': '#PojokSatu Foto Salaman dengan Raja Salman Disebut Hoax, #Ahok Kegirangan https://t.co/yruLifFRYW #nasional',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Nov 27 11:32:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 537,
#    'following': None,
#    'friends_count': 525,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 802837437667897344,
#    'id_str': '802837437667897344',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'id',
#    'listed_count': 9,
#    'location': 'Los Angeles, CA',
#    'name': 'agnes aulia',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/802837437667897344/1480248907',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/802847817257480192/hrhvdQm6_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/802847817257480192/hrhvdQm6_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'agnes_auliaa',
#    'statuses_count': 6533,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 15:18:12 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1569342572,
#      'id_str': '1569342572',
#      'indices': [3, 12],
#      'name': 'akhmad sahal',
#      'screen_name': 'sahaL_AS'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836958759352053762,
#   'id_str': '836958759352053762',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'in',
#   'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#   'place': None,
#   'quoted_status_id': 836830538711384064,
#   'quoted_status_id_str': '836830538711384064',
#   'retweet_count': 343,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 09:32:46 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/836871826164879360',
#       'indices': [117, 140],
#       'url': 'https://t.co/KBPiWZRG1c'}],
#     'user_mentions': []},
#    'favorite_count': 282,
#    'favorited': False,
#    'geo': None,
#    'id': 836871826164879360,
#    'id_str': '836871826164879360',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': True,
#    'lang': 'in',
#    'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'quoted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 01 06:48:42 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#        'expanded_url': 'https://twitter.com/i/web/status/836830538711384064',
#        'indices': [117, 140],
#        'url': 'https://t.co/AbBbf24C1K'}],
#      'user_mentions': []},
#     'favorite_count': 1125,
#     'favorited': False,
#     'geo': None,
#     'id': 836830538711384064,
#     'id_str': '836830538711384064',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'in',
#     'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1515,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': 'Dicap penista agama, dikafir2kan di khutbah2, didemo "7 juta", pendukungnya yg muslim dicap munafik, ehh..salaman d… https://t.co/AbBbf24C1K',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Jul 05 00:05:59 +0000 2013',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'University of Pennsylvania; Pengurus Cabang Istimewa NU (PCINU) Amerika',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 7905,
#      'follow_request_sent': None,
#      'followers_count': 116328,
#      'following': None,
#      'friends_count': 8682,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 1569342572,
#      'id_str': '1569342572',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 247,
#      'location': 'Philadelphia, PA',
#      'name': 'akhmad sahal',
#      'notifications': None,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1569342572/1476395618',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'sahaL_AS',
#      'statuses_count': 77716,
#      'time_zone': 'Atlantic Time (Canada)',
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': -14400,
#      'verified': False}},
#    'quoted_status_id': 836830538711384064,
#    'quoted_status_id_str': '836830538711384064',
#    'retweet_count': 343,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Ini bukan memuja2 Raja Salman, atau pro Wahabisme. Kita ngetawa'in Rizieq Shihab cs yg udah cape2 mencap Ahok penis… https://t.co/KBPiWZRG1c",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jul 05 00:05:59 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'University of Pennsylvania; Pengurus Cabang Istimewa NU (PCINU) Amerika',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 7905,
#     'follow_request_sent': None,
#     'followers_count': 116328,
#     'following': None,
#     'friends_count': 8682,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 1569342572,
#     'id_str': '1569342572',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 247,
#     'location': 'Philadelphia, PA',
#     'name': 'akhmad sahal',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1569342572/1476395618',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'sahaL_AS',
#     'statuses_count': 77716,
#     'time_zone': 'Atlantic Time (Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': "RT @sahaL_AS: Ini bukan memuja2 Raja Salman, atau pro Wahabisme. Kita ngetawa'in Rizieq Shihab cs yg udah cape2 mencap Ahok penista agama,…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jan 28 01:25:29 +0000 2012',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '❤ Filipi 4 : 13 ❤\n\n\n|| in JESUS i TRUST || #PernahGanteng 😎',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 498,
#    'follow_request_sent': None,
#    'followers_count': 601,
#    'following': None,
#    'friends_count': 310,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 476340620,
#    'id_str': '476340620',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'id',
#    'listed_count': 15,
#    'location': '* KUTA ROCK CITY *',
#    'name': '• Reyes De Europa11•',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/476340620/1474290020',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/834236532886233089/wX0F0Ar2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/834236532886233089/wX0F0Ar2_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'togarerwin24',
#    'statuses_count': 47145,
#    'time_zone': 'Bangkok',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 25200,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 15:17:02 +0000 2017',
#   'entities': {'hashtags': [{'indices': [46, 51], 'text': 'Ahok'},
#     {'indices': [87, 96], 'text': 'nasional'},
#     {'indices': [97, 111], 'text': 'rajaarabsaudi'}],
#    'symbols': [],
#    'urls': [{'display_url': 'goo.gl/fb/IkG5Ib',
#      'expanded_url': 'https://goo.gl/fb/IkG5Ib',
#      'indices': [63, 86],
#      'url': 'https://t.co/kLzgyNNvJo'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836958463179784192,
#   'id_str': '836958463179784192',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'in',
#   'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.google.com/" rel="nofollow">Google</a>',
#   'text': 'Foto Salaman dengan Raja Salman Disebut Hoax, #Ahok Kegirangan https://t.co/kLzgyNNvJo #nasional #rajaarabsaudi',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Feb 08 08:01:16 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 2,
#    'following': None,
#    'friends_count': 100,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 829238654157594625,
#    'id_str': '829238654157594625',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'id',
#    'listed_count': 0,
#    'location': 'New York, NY',
#    'name': 'Ricis',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/829238654157594625/1486541191',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/829239683381071880/3qbQBU5q_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/829239683381071880/3qbQBU5q_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': '27Ricis',
#    'statuses_count': 1471,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 15:16:03 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1569342572,
#      'id_str': '1569342572',
#      'indices': [3, 12],
#      'name': 'akhmad sahal',
#      'screen_name': 'sahaL_AS'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836958217389268993,
#   'id_str': '836958217389268993',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'in',
#   'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#   'place': None,
#   'quoted_status_id': 836830538711384064,
#   'quoted_status_id_str': '836830538711384064',
#   'retweet_count': 343,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 09:32:46 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/836871826164879360',
#       'indices': [117, 140],
#       'url': 'https://t.co/KBPiWZRG1c'}],
#     'user_mentions': []},
#    'favorite_count': 282,
#    'favorited': False,
#    'geo': None,
#    'id': 836871826164879360,
#    'id_str': '836871826164879360',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': True,
#    'lang': 'in',
#    'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'quoted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 01 06:48:42 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#        'expanded_url': 'https://twitter.com/i/web/status/836830538711384064',
#        'indices': [117, 140],
#        'url': 'https://t.co/AbBbf24C1K'}],
#      'user_mentions': []},
#     'favorite_count': 1125,
#     'favorited': False,
#     'geo': None,
#     'id': 836830538711384064,
#     'id_str': '836830538711384064',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'in',
#     'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1515,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': 'Dicap penista agama, dikafir2kan di khutbah2, didemo "7 juta", pendukungnya yg muslim dicap munafik, ehh..salaman d… https://t.co/AbBbf24C1K',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Jul 05 00:05:59 +0000 2013',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'University of Pennsylvania; Pengurus Cabang Istimewa NU (PCINU) Amerika',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 7905,
#      'follow_request_sent': None,
#      'followers_count': 116328,
#      'following': None,
#      'friends_count': 8682,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 1569342572,
#      'id_str': '1569342572',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 247,
#      'location': 'Philadelphia, PA',
#      'name': 'akhmad sahal',
#      'notifications': None,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1569342572/1476395618',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'sahaL_AS',
#      'statuses_count': 77716,
#      'time_zone': 'Atlantic Time (Canada)',
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': -14400,
#      'verified': False}},
#    'quoted_status_id': 836830538711384064,
#    'quoted_status_id_str': '836830538711384064',
#    'retweet_count': 343,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Ini bukan memuja2 Raja Salman, atau pro Wahabisme. Kita ngetawa'in Rizieq Shihab cs yg udah cape2 mencap Ahok penis… https://t.co/KBPiWZRG1c",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jul 05 00:05:59 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'University of Pennsylvania; Pengurus Cabang Istimewa NU (PCINU) Amerika',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 7905,
#     'follow_request_sent': None,
#     'followers_count': 116328,
#     'following': None,
#     'friends_count': 8682,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 1569342572,
#     'id_str': '1569342572',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 247,
#     'location': 'Philadelphia, PA',
#     'name': 'akhmad sahal',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1569342572/1476395618',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'sahaL_AS',
#     'statuses_count': 77716,
#     'time_zone': 'Atlantic Time (Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': "RT @sahaL_AS: Ini bukan memuja2 Raja Salman, atau pro Wahabisme. Kita ngetawa'in Rizieq Shihab cs yg udah cape2 mencap Ahok penista agama,…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Sep 08 10:25:04 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Pendukung berat @KPK_RI || The 12th player of @FCBarcelona ||  #ngAHOK || VVOTA @officialJKT48',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 872,
#    'follow_request_sent': None,
#    'followers_count': 85,
#    'following': None,
#    'friends_count': 188,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 370026775,
#    'id_str': '370026775',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'id',
#    'listed_count': 2,
#    'location': 'DKI Jakarta, Indonesia',
#    'name': 'нεгησίsм',
#    'notifications': None,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/370026775/1377959384',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/800340764211302400/zX1388cY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800340764211302400/zX1388cY_normal.jpg',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Hernoism',
#    'statuses_count': 9174,
#    'time_zone': 'Jakarta',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 25200,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 15:15:20 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1569342572,
#      'id_str': '1569342572',
#      'indices': [3, 12],
#      'name': 'akhmad sahal',
#      'screen_name': 'sahaL_AS'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836958037378129920,
#   'id_str': '836958037378129920',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'in',
#   'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#   'place': None,
#   'quoted_status_id': 836855070415273987,
#   'quoted_status_id_str': '836855070415273987',
#   'retweet_count': 98,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 09:43:27 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/836874515296698369',
#       'indices': [117, 140],
#       'url': 'https://t.co/34WZ3oUf6K'}],
#     'user_mentions': []},
#    'favorite_count': 66,
#    'favorited': False,
#    'geo': None,
#    'id': 836874515296698369,
#    'id_str': '836874515296698369',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': True,
#    'lang': 'in',
#    'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'quoted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 01 08:26:11 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'favorite_count': 327,
#     'favorited': False,
#     'geo': None,
#     'id': 836855070415273987,
#     'id_str': '836855070415273987',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'in',
#     'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 543,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': 'Setahun loe disuruh maki" wahabi. Hari ini loe disuruh kasih tepuk tangan buat junjungan loe yg salaman ama Rajanya. Ngga korslet otak loe?',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Dec 20 14:11:22 +0000 2010',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': "I am not a funny guy. i've made a peace with that. But I still can make you smile, if that is what you want.",
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'ardiwirdamulia.com',
#          'expanded_url': 'http://ardiwirdamulia.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/0FISkzCUA0'}]}},
#      'favourites_count': 0,
#      'follow_request_sent': None,
#      'followers_count': 13326,
#      'following': None,
#      'friends_count': 901,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 228724587,
#      'id_str': '228724587',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 67,
#      'location': '',
#      'name': 'Pelan-pelan, Ardi!',
#      'notifications': None,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/777772760953073664/W1GmV8lv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/777772760953073664/W1GmV8lv_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'awemany',
#      'statuses_count': 51250,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/0FISkzCUA0',
#      'utc_offset': None,
#      'verified': False}},
#    'quoted_status_id': 836855070415273987,
#    'quoted_status_id_str': '836855070415273987',
#    'retweet_count': 98,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Bukan pro Wahabisme, tp ngetawa'in FPI cs yg mencap Ahok penista agama, krn mrk ga direken ama Raja Salman yg tetep… https://t.co/34WZ3oUf6K",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jul 05 00:05:59 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'University of Pennsylvania; Pengurus Cabang Istimewa NU (PCINU) Amerika',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 7905,
#     'follow_request_sent': None,
#     'followers_count': 116328,
#     'following': None,
#     'friends_count': 8682,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 1569342572,
#     'id_str': '1569342572',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 247,
#     'location': 'Philadelphia, PA',
#     'name': 'akhmad sahal',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1569342572/1476395618',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'sahaL_AS',
#     'statuses_count': 77716,
#     'time_zone': 'Atlantic Time (Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': "RT @sahaL_AS: Bukan pro Wahabisme, tp ngetawa'in FPI cs yg mencap Ahok penista agama, krn mrk ga direken ama Raja Salman yg tetep mau salam…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Sep 08 10:25:04 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Pendukung berat @KPK_RI || The 12th player of @FCBarcelona ||  #ngAHOK || VVOTA @officialJKT48',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 872,
#    'follow_request_sent': None,
#    'followers_count': 85,
#    'following': None,
#    'friends_count': 188,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 370026775,
#    'id_str': '370026775',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'id',
#    'listed_count': 2,
#    'location': 'DKI Jakarta, Indonesia',
#    'name': 'нεгησίsм',
#    'notifications': None,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/370026775/1377959384',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/800340764211302400/zX1388cY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800340764211302400/zX1388cY_normal.jpg',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Hernoism',
#    'statuses_count': 9174,
#    'time_zone': 'Jakarta',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 25200,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 15:14:00 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1569342572,
#      'id_str': '1569342572',
#      'indices': [3, 12],
#      'name': 'akhmad sahal',
#      'screen_name': 'sahaL_AS'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836957700881723393,
#   'id_str': '836957700881723393',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'in',
#   'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#   'place': None,
#   'quoted_status_id': 836830538711384064,
#   'quoted_status_id_str': '836830538711384064',
#   'retweet_count': 343,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 09:32:46 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/836871826164879360',
#       'indices': [117, 140],
#       'url': 'https://t.co/KBPiWZRG1c'}],
#     'user_mentions': []},
#    'favorite_count': 282,
#    'favorited': False,
#    'geo': None,
#    'id': 836871826164879360,
#    'id_str': '836871826164879360',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': True,
#    'lang': 'in',
#    'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'quoted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 01 06:48:42 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#        'expanded_url': 'https://twitter.com/i/web/status/836830538711384064',
#        'indices': [117, 140],
#        'url': 'https://t.co/AbBbf24C1K'}],
#      'user_mentions': []},
#     'favorite_count': 1125,
#     'favorited': False,
#     'geo': None,
#     'id': 836830538711384064,
#     'id_str': '836830538711384064',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'in',
#     'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1515,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': 'Dicap penista agama, dikafir2kan di khutbah2, didemo "7 juta", pendukungnya yg muslim dicap munafik, ehh..salaman d… https://t.co/AbBbf24C1K',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Jul 05 00:05:59 +0000 2013',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'University of Pennsylvania; Pengurus Cabang Istimewa NU (PCINU) Amerika',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 7905,
#      'follow_request_sent': None,
#      'followers_count': 116328,
#      'following': None,
#      'friends_count': 8682,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 1569342572,
#      'id_str': '1569342572',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 247,
#      'location': 'Philadelphia, PA',
#      'name': 'akhmad sahal',
#      'notifications': None,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1569342572/1476395618',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'sahaL_AS',
#      'statuses_count': 77716,
#      'time_zone': 'Atlantic Time (Canada)',
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': -14400,
#      'verified': False}},
#    'quoted_status_id': 836830538711384064,
#    'quoted_status_id_str': '836830538711384064',
#    'retweet_count': 343,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Ini bukan memuja2 Raja Salman, atau pro Wahabisme. Kita ngetawa'in Rizieq Shihab cs yg udah cape2 mencap Ahok penis… https://t.co/KBPiWZRG1c",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jul 05 00:05:59 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'University of Pennsylvania; Pengurus Cabang Istimewa NU (PCINU) Amerika',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 7905,
#     'follow_request_sent': None,
#     'followers_count': 116328,
#     'following': None,
#     'friends_count': 8682,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 1569342572,
#     'id_str': '1569342572',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 247,
#     'location': 'Philadelphia, PA',
#     'name': 'akhmad sahal',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1569342572/1476395618',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'sahaL_AS',
#     'statuses_count': 77716,
#     'time_zone': 'Atlantic Time (Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': "RT @sahaL_AS: Ini bukan memuja2 Raja Salman, atau pro Wahabisme. Kita ngetawa'in Rizieq Shihab cs yg udah cape2 mencap Ahok penista agama,…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Sep 19 04:54:11 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Mind Wanderer - ARSenal (Prem.) - RMa (BBVA)',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 205,
#    'follow_request_sent': None,
#    'followers_count': 384,
#    'following': None,
#    'friends_count': 991,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 3612490633,
#    'id_str': '3612490633',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 147,
#    'location': '',
#    'name': 'Boby_ngr',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/818527407430725632/mVCEIJUN_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/818527407430725632/mVCEIJUN_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'bobngr',
#    'statuses_count': 42772,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 15:10:12 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/detikcom/statu…',
#      'expanded_url': 'https://twitter.com/detikcom/status/836565754447192067',
#      'indices': [75, 98],
#      'url': 'https://t.co/lLa2cq1Zlg'}],
#    'user_mentions': [{'id': 1569342572,
#      'id_str': '1569342572',
#      'indices': [3, 12],
#      'name': 'akhmad sahal',
#      'screen_name': 'sahaL_AS'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836956743632498688,
#   'id_str': '836956743632498688',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'in',
#   'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status_id': 836565754447192067,
#   'quoted_status_id_str': '836565754447192067',
#   'retweet_count': 106,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 08:11:29 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/detikcom/statu…',
# ...
#    'place': None,
#    'possibly_sensitive': False,
#    'quoted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 01 08:26:11 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'favorite_count': 327,
#     'favorited': False,
#     'geo': None,
#     'id': 836855070415273987,
#     'id_str': '836855070415273987',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'in',
#     'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 543,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': 'Setahun loe disuruh maki" wahabi. Hari ini loe disuruh kasih tepuk tangan buat junjungan loe yg salaman ama Rajanya. Ngga korslet otak loe?',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Dec 20 14:11:22 +0000 2010',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': "I am not a funny guy. i've made a peace with that. But I still can make you smile, if that is what you want.",
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'ardiwirdamulia.com',
#          'expanded_url': 'http://ardiwirdamulia.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/0FISkzCUA0'}]}},
#      'favourites_count': 0,
#      'follow_request_sent': None,
#      'followers_count': 13326,
#      'following': None,
#      'friends_count': 901,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 228724587,
#      'id_str': '228724587',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 67,
#      'location': '',
#      'name': 'Pelan-pelan, Ardi!',
#      'notifications': None,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/777772760953073664/W1GmV8lv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/777772760953073664/W1GmV8lv_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'awemany',
#      'statuses_count': 51250,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/0FISkzCUA0',
#      'utc_offset': None,
#      'verified': False}},
#    'quoted_status_id': 836855070415273987,
#    'quoted_status_id_str': '836855070415273987',
#    'retweet_count': 98,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Bukan pro Wahabisme, tp ngetawa'in FPI cs yg mencap Ahok penista agama, krn mrk ga direken ama Raja Salman yg tetep… https://t.co/34WZ3oUf6K",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jul 05 00:05:59 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'University of Pennsylvania; Pengurus Cabang Istimewa NU (PCINU) Amerika',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 7905,
#     'follow_request_sent': None,
#     'followers_count': 116328,
#     'following': None,
#     'friends_count': 8682,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 1569342572,
#     'id_str': '1569342572',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 247,
#     'location': 'Philadelphia, PA',
#     'name': 'akhmad sahal',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1569342572/1476395618',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'sahaL_AS',
#     'statuses_count': 77716,
#     'time_zone': 'Atlantic Time (Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "RT @sahaL_AS: Bukan pro Wahabisme, tp ngetawa'in FPI cs yg mencap Ahok penista agama, krn mrk ga direken ama Raja Salman yg tetep mau salam…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Oct 25 18:12:28 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Umat islam siap REVOLUSI',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1967,
#    'follow_request_sent': None,
#    'followers_count': 1189,
#    'following': None,
#    'friends_count': 804,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 790979353773432832,
#    'id_str': '790979353773432832',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'id',
#    'listed_count': 7,
#    'location': 'DKI Jakarta, Indonesia',
#    'name': 'Banteng Betawi',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/790979353773432832/1485783630',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/831841748196352001/hEIzlKtn_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/831841748196352001/hEIzlKtn_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Jaelani92145365',
#    'statuses_count': 30496,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 13:32:00 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1569342572,
#      'id_str': '1569342572',
#      'indices': [3, 12],
#      'name': 'akhmad sahal',
#      'screen_name': 'sahaL_AS'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836932032164941828,
#   'id_str': '836932032164941828',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'in',
#   'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#   'place': None,
#   'quoted_status_id': 836830538711384064,
#   'quoted_status_id_str': '836830538711384064',
#   'retweet_count': 343,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 09:32:46 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/836871826164879360',
#       'indices': [117, 140],
#       'url': 'https://t.co/KBPiWZRG1c'}],
#     'user_mentions': []},
#    'favorite_count': 282,
#    'favorited': False,
#    'geo': None,
#    'id': 836871826164879360,
#    'id_str': '836871826164879360',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': True,
#    'lang': 'in',
#    'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'quoted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 01 06:48:42 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#        'expanded_url': 'https://twitter.com/i/web/status/836830538711384064',
#        'indices': [117, 140],
#        'url': 'https://t.co/AbBbf24C1K'}],
#      'user_mentions': []},
#     'favorite_count': 1125,
#     'favorited': False,
#     'geo': None,
#     'id': 836830538711384064,
#     'id_str': '836830538711384064',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'in',
#     'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1515,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': 'Dicap penista agama, dikafir2kan di khutbah2, didemo "7 juta", pendukungnya yg muslim dicap munafik, ehh..salaman d… https://t.co/AbBbf24C1K',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Jul 05 00:05:59 +0000 2013',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'University of Pennsylvania; Pengurus Cabang Istimewa NU (PCINU) Amerika',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 7905,
#      'follow_request_sent': None,
#      'followers_count': 116328,
#      'following': None,
#      'friends_count': 8682,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 1569342572,
#      'id_str': '1569342572',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 247,
#      'location': 'Philadelphia, PA',
#      'name': 'akhmad sahal',
#      'notifications': None,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1569342572/1476395618',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'sahaL_AS',
#      'statuses_count': 77716,
#      'time_zone': 'Atlantic Time (Canada)',
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': -14400,
#      'verified': False}},
#    'quoted_status_id': 836830538711384064,
#    'quoted_status_id_str': '836830538711384064',
#    'retweet_count': 343,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Ini bukan memuja2 Raja Salman, atau pro Wahabisme. Kita ngetawa'in Rizieq Shihab cs yg udah cape2 mencap Ahok penis… https://t.co/KBPiWZRG1c",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jul 05 00:05:59 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'University of Pennsylvania; Pengurus Cabang Istimewa NU (PCINU) Amerika',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 7905,
#     'follow_request_sent': None,
#     'followers_count': 116328,
#     'following': None,
#     'friends_count': 8682,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 1569342572,
#     'id_str': '1569342572',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 247,
#     'location': 'Philadelphia, PA',
#     'name': 'akhmad sahal',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1569342572/1476395618',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800932635510009856/pUKaWwXn_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'sahaL_AS',
#     'statuses_count': 77716,
#     'time_zone': 'Atlantic Time (Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "RT @sahaL_AS: Ini bukan memuja2 Raja Salman, atau pro Wahabisme. Kita ngetawa'in Rizieq Shihab cs yg udah cape2 mencap Ahok penista agama,…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jun 12 06:13:00 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Middle-class Indonesian. @uniofleicester alumni. Heart belongs to @Yukiriiiin__K . Verbis defectis musica incipit.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 3479,
#    'follow_request_sent': None,
#    'followers_count': 655,
#    'following': None,
#    'friends_count': 1361,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 46595577,
#    'id_str': '46595577',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 8,
#    'location': 'Yogyakarta, Indonesia',
#    'name': 'Haryo P Jiwandono',
#    'notifications': None,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/132257465/CaseyTranZam.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/132257465/CaseyTranZam.jpg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/46595577/1418402577',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/804727385446825984/gg9JQAsS_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/804727385446825984/gg9JQAsS_normal.jpg',
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'iwokroxx',
#    'statuses_count': 60070,
#    'time_zone': 'Jakarta',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 25200,
#    'verified': False}}]

# %% [markdown]
# ### 4. Automate it - Hit the API and Parse the Result
#
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure.
#
# It can be sometimes hard to read a raw JSON. I find it easy to use some online parsers like [this]( http://jsonparseronline.com/) to look at the structure of the JSON, and only access what we care about.
#
# Note: Remember we are limited to 450 every 15 minutes.

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 10
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 5
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %% [markdown]
# ### 5. Run the Twitter Scraper
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called **data**, where I am saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like [threading](https://docs.python.org/3.6/library/threading.html).
#
# *Make sure you have a folder named **data** in the directory with your notebook! This function will save our collected datafiles to it when it finishes running.*

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run_all()
# Out:
# At 0 seconds, added 100 new tweets, for a total of 100
# At 5 seconds, added 0 new tweets, for a total of 100
# 100 Tweets retrieved.

# %% [markdown]
# ### 6. Let's Explore the Data we Saved to our Machine
#
# Let's look through the JSON we created and checkout some of the data we just downloaded. First, let's import a couple of additional libraries that will let us interact with our file system, use numpy and pandas, and create plots:

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, let's explore our data a bit. This following function will allow us to perform a visual examination of what we downloaded from Twitter. Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.
#
# Building on last week, we can do this in Pandas.

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets
# Out:
#                               tweet_id   lat   lon  \
# 836961829469347841  836961829469347841  None  None
# 836961765250367488  836961765250367488  None  None
# 836961655250542593  836961655250542593  None  None
# 836961448626548740  836961448626548740  None  None
# 836960541268557824  836960541268557824  None  None
# 836960498536980481  836960498536980481  None  None
# 836959473457516544  836959473457516544  None  None
# 836959411818016768  836959411818016768  None  None
# 836958908178542592  836958908178542592  None  None
# 836958762594406400  836958762594406400  None  None
# 836958759352053762  836958759352053762  None  None
# 836958463179784192  836958463179784192  None  None
# 836958217389268993  836958217389268993  None  None
# 836958037378129920  836958037378129920  None  None
# 836957700881723393  836957700881723393  None  None
# 836956743632498688  836956743632498688  None  None
# 836955962749534211  836955962749534211  None  None
# 836955793886871553  836955793886871553  None  None
# 836955376264192000  836955376264192000  None  None
# 836955096630046720  836955096630046720  None  None
# 836955080725168131  836955080725168131  None  None
# 836954878287065088  836954878287065088  None  None
# 836954762335551488  836954762335551488  None  None
# 836954756895551488  836954756895551488  None  None
# 836954755435941889  836954755435941889  None  None
# 836954754433495041  836954754433495041  None  None
# 836954622069628928  836954622069628928  None  None
# 836953983868493824  836953983868493824  None  None
# 836953793073860608  836953793073860608  None  None
# 836952973246812160  836952973246812160  None  None
# ...                                ...   ...   ...
# 836943112530350082  836943112530350082  None  None
# 836942891150868485  836942891150868485  None  None
# 836942622832930817  836942622832930817  None  None
# 836941753009631233  836941753009631233  None  None
# 836941694578798592  836941694578798592  None  None
# 836941635858608133  836941635858608133  None  None
# 836941541818040320  836941541818040320  None  None
# 836941535300071424  836941535300071424  None  None
# 836941522432049152  836941522432049152  None  None
# 836941346539646980  836941346539646980  None  None
# 836940897317089280  836940897317089280  None  None
# 836940849799806976  836940849799806976  None  None
# 836940274215473152  836940274215473152  None  None
# 836939995797585920  836939995797585920  None  None
# 836939607103004675  836939607103004675  None  None
# 836939034383392768  836939034383392768  None  None
# 836939022643580931  836939022643580931  None  None
# 836938619055026176  836938619055026176  None  None
# 836938502335954944  836938502335954944  None  None
# 836938397843238912  836938397843238912  None  None
# 836937664032956416  836937664032956416  None  None
# 836937404392992770  836937404392992770  None  None
# 836936758537273344  836936758537273344  None  None
# 836936611363344390  836936611363344390  None  None
# 836936079139753985  836936079139753985  None  None
# 836935629439025152  836935629439025152  None  None
# 836935482739044354  836935482739044354  None  None
# 836935374899306497  836935374899306497  None  None
# 836935174306721792  836935174306721792  None  None
# 836934881317801984  836934881317801984  None  None
#
#                                                               content  \
# 836961829469347841  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836961765250367488  RT @sahaL_AS: Bukan pro Wahabisme, tp ngetawa'...
# 836961655250542593  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836961448626548740  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836960541268557824  RT @sahaL_AS: Bukan pro Wahabisme, tp ngetawa'...
# 836960498536980481  Ini Ahok pake kacamata item kenapa jadi makin ...
# 836959473457516544  RT @sahaL_AS: Padahal Raja Salman salaman sama...
# 836959411818016768  RAPOPO Paduka Yang Mulia, saya dan rakyat juga...
# 836958908178542592  Yg menentukan penista agama atau bukan adalah ...
# 836958762594406400  #PojokSatu Foto Salaman dengan Raja Salman Dis...
# 836958759352053762  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836958463179784192  Foto Salaman dengan Raja Salman Disebut Hoax, ...
# 836958217389268993  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836958037378129920  RT @sahaL_AS: Bukan pro Wahabisme, tp ngetawa'...
# 836957700881723393  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836956743632498688  RT @sahaL_AS: Padahal Raja Salman salaman sama...
# 836955962749534211  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836955793886871553  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836955376264192000  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836955096630046720  Foto Salaman dengan Raja Salman Disebut Hoax, ...
# 836955080725168131  RT @sahaL_AS: Mungkin Raja Salman pengen nunju...
# 836954878287065088  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836954762335551488  RT @sahaL_AS: Mungkin Raja Salman pengen nunju...
# 836954756895551488  RT @sahaL_AS: Bukan pro Wahabisme, tp ngetawa'...
# 836954755435941889  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836954754433495041  RT @sahaL_AS: Mungkin Raja Salman pengen nunju...
# 836954622069628928  RT @sahaL_AS: Padahal Raja Salman salaman sama...
# 836953983868493824  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836953793073860608  Si Bakpao isi granat lg pegang panci. Mau bunu...
# 836952973246812160  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# ...                                                               ...
# 836943112530350082  RT @BULLFRONT: Resmikan Jakarta Creative Hub, ...
# 836942891150868485  Saya suka video @YouTube https://t.co/VqR3vLCM...
# 836942622832930817  Saya suka video @YouTube https://t.co/aYUkxITW...
# 836941753009631233  RT @sahaL_AS: Mungkin Raja Salman pengen nunju...
# 836941694578798592  RT @AKUL52805989: @basuki_btp Si Habieb aja be...
# 836941635858608133  Ahok's Lawyers Reject Testimony by Prosecution...
# 836941541818040320  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836941535300071424  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836941522432049152  Sambut Raja Salman, Nikita Mirzani Sebut #Ahok...
# 836941346539646980  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836940897317089280  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836940849799806976  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836940274215473152  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836939995797585920  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836939607103004675  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836939034383392768  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836939022643580931  RT @DodolDolanan: Klo scr halus org jawa jls k...
# 836938619055026176  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836938502335954944  RT @BULLFRONT: Ahok dikenalkan kepada Raja Sal...
# 836938397843238912  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836937664032956416  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836937404392992770  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836936758537273344  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836936611363344390  Anda sendiri selain terdakwa penista agama jg ...
# 836936079139753985  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836935629439025152  RT @BULLFRONT: Resmikan Jakarta Creative Hub, ...
# 836935482739044354  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836935374899306497  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836935174306721792  RT @sahaL_AS: Ini bukan memuja2 Raja Salman, a...
# 836934881317801984  RT @sahaL_AS: Bukan pro Wahabisme, tp ngetawa'...
#
#                                          location                user  \
# 836961829469347841                      Indonesia           122287944
# 836961765250367488           Sidoarjo, Jawa Timur            85567629
# 836961655250542593                    Tanah Jawa             77555749
# 836961448626548740                                           58406008
# 836960541268557824               Papua, Indonesia           338170491
# 836960498536980481                           home          3913232353
# 836959473457516544                                 793302435020152832
# 836959411818016768                      Australia            99091448
# 836958908178542592                      Australia            99091448
# 836958762594406400                Los Angeles, CA  802837437667897344
# 836958759352053762             * KUTA ROCK CITY *           476340620
# 836958463179784192                   New York, NY  829238654157594625
# 836958217389268993         DKI Jakarta, Indonesia           370026775
# 836958037378129920         DKI Jakarta, Indonesia           370026775
# 836957700881723393                                         3612490633
# 836956743632498688           Simokerto, Indonesia           740944226
# 836955962749534211            disini, nah disitu.           259252923
# 836955793886871553              Tangerang, Banten           792805483
# 836955376264192000                                          479266773
# 836955096630046720                   New York, NY  829226780858970113
# 836955080725168131                Denpasar - Bali            88099981
# 836954878287065088                                          582997448
# 836954762335551488   @-6.325379,106.79370171,803m           562311857
# 836954756895551488   @-6.325379,106.79370171,803m           562311857
# 836954755435941889   @-6.325379,106.79370171,803m           562311857
# 836954754433495041                    ÜT: 0.0,0.0           112637174
# 836954622069628928                    ÜT: 0.0,0.0           112637174
# 836953983868493824                       Jakarta            130795358
# 836953793073860608                    Seattle, WA  806915251480379392
# 836952973246812160      Central Region, Singapore          2783528108
# ...                                           ...                 ...
# 836943112530350082         DKI Jakarta, Indonesia          3304289798
# 836942891150868485                          earth           235945378
# 836942622832930817                          earth           235945378
# 836941753009631233                                 750373287931187200
# 836941694578798592        Anywhere I Wanted To Be           256394288
# 836941635858608133                Orlando,Florida           501346233
# 836941541818040320            jakartans - cirebon           629146502
# 836941535300071424                          earth          2802114039
# 836941522432049152                  Manhattan, NY  829233895124131840
# 836941346539646980                            +62          4834489926
# 836940897317089280          Deket colokan listrik           108523246
# 836940849799806976                                          531016032
# 836940274215473152               Uppsala, Sverige            30768140
# 836939995797585920      Bandung - Bogor - Lampung           938484181
# 836939607103004675                                 723480712758726657
# 836939034383392768                                 828974932688121857
# 836939022643580931         DKI Jakarta, Indonesia  790979353773432832
# 836938619055026176      Sumatera Utara, Indonesia  832815282938793985
# 836938502335954944                      Indonesia  804299423194849280
# 836938397843238912         di kota macet + banjir           274552633
# 836937664032956416  DKI Jakarta, Indonesia Border           462170742
# 836937404392992770                      Indonesia           166630481
# 836936758537273344                                         1604067218
# 836936611363344390                           Mars            37869737
# 836936079139753985                                          147765878
# 836935629439025152       Somewhere only we know..           133664013
# 836935482739044354        Bandar Lampung, Lampung  812466633335635969
# 836935374899306497                                         1333267518
# 836935174306721792                                           83871706
# 836934881317801984   Ngalam, East Java, Indonesia          4886540652
#
#                                                            raw_source  \
# 836961829469347841  {'created_at': 'Wed Mar 01 15:30:24 +0000 2017...
# 836961765250367488  {'created_at': 'Wed Mar 01 15:30:09 +0000 2017...
# 836961655250542593  {'created_at': 'Wed Mar 01 15:29:43 +0000 2017...
# 836961448626548740  {'created_at': 'Wed Mar 01 15:28:54 +0000 2017...
# 836960541268557824  {'created_at': 'Wed Mar 01 15:25:17 +0000 2017...
# 836960498536980481  {'created_at': 'Wed Mar 01 15:25:07 +0000 2017...
# 836959473457516544  {'created_at': 'Wed Mar 01 15:21:03 +0000 2017...
# 836959411818016768  {'created_at': 'Wed Mar 01 15:20:48 +0000 2017...
# 836958908178542592  {'created_at': 'Wed Mar 01 15:18:48 +0000 2017...
# 836958762594406400  {'created_at': 'Wed Mar 01 15:18:13 +0000 2017...
# 836958759352053762  {'created_at': 'Wed Mar 01 15:18:12 +0000 2017...
# 836958463179784192  {'created_at': 'Wed Mar 01 15:17:02 +0000 2017...
# 836958217389268993  {'created_at': 'Wed Mar 01 15:16:03 +0000 2017...
# 836958037378129920  {'created_at': 'Wed Mar 01 15:15:20 +0000 2017...
# 836957700881723393  {'created_at': 'Wed Mar 01 15:14:00 +0000 2017...
# 836956743632498688  {'created_at': 'Wed Mar 01 15:10:12 +0000 2017...
# 836955962749534211  {'created_at': 'Wed Mar 01 15:07:06 +0000 2017...
# 836955793886871553  {'created_at': 'Wed Mar 01 15:06:25 +0000 2017...
# 836955376264192000  {'created_at': 'Wed Mar 01 15:04:46 +0000 2017...
# 836955096630046720  {'created_at': 'Wed Mar 01 15:03:39 +0000 2017...
# 836955080725168131  {'created_at': 'Wed Mar 01 15:03:35 +0000 2017...
# 836954878287065088  {'created_at': 'Wed Mar 01 15:02:47 +0000 2017...
# 836954762335551488  {'created_at': 'Wed Mar 01 15:02:19 +0000 2017...
# 836954756895551488  {'created_at': 'Wed Mar 01 15:02:18 +0000 2017...
# 836954755435941889  {'created_at': 'Wed Mar 01 15:02:18 +0000 2017...
# 836954754433495041  {'created_at': 'Wed Mar 01 15:02:17 +0000 2017...
# 836954622069628928  {'created_at': 'Wed Mar 01 15:01:46 +0000 2017...
# 836953983868493824  {'created_at': 'Wed Mar 01 14:59:14 +0000 2017...
# 836953793073860608  {'created_at': 'Wed Mar 01 14:58:28 +0000 2017...
# 836952973246812160  {'created_at': 'Wed Mar 01 14:55:13 +0000 2017...
# ...                                                               ...
# 836943112530350082  {'created_at': 'Wed Mar 01 14:16:02 +0000 2017...
# 836942891150868485  {'created_at': 'Wed Mar 01 14:15:09 +0000 2017...
# 836942622832930817  {'created_at': 'Wed Mar 01 14:14:05 +0000 2017...
# 836941753009631233  {'created_at': 'Wed Mar 01 14:10:38 +0000 2017...
# 836941694578798592  {'created_at': 'Wed Mar 01 14:10:24 +0000 2017...
# 836941635858608133  {'created_at': 'Wed Mar 01 14:10:10 +0000 2017...
# 836941541818040320  {'created_at': 'Wed Mar 01 14:09:47 +0000 2017...
# 836941535300071424  {'created_at': 'Wed Mar 01 14:09:46 +0000 2017...
# 836941522432049152  {'created_at': 'Wed Mar 01 14:09:43 +0000 2017...
# 836941346539646980  {'created_at': 'Wed Mar 01 14:09:01 +0000 2017...
# 836940897317089280  {'created_at': 'Wed Mar 01 14:07:14 +0000 2017...
# 836940849799806976  {'created_at': 'Wed Mar 01 14:07:02 +0000 2017...
# 836940274215473152  {'created_at': 'Wed Mar 01 14:04:45 +0000 2017...
# 836939995797585920  {'created_at': 'Wed Mar 01 14:03:39 +0000 2017...
# 836939607103004675  {'created_at': 'Wed Mar 01 14:02:06 +0000 2017...
# 836939034383392768  {'created_at': 'Wed Mar 01 13:59:50 +0000 2017...
# 836939022643580931  {'created_at': 'Wed Mar 01 13:59:47 +0000 2017...
# 836938619055026176  {'created_at': 'Wed Mar 01 13:58:11 +0000 2017...
# 836938502335954944  {'created_at': 'Wed Mar 01 13:57:43 +0000 2017...
# 836938397843238912  {'created_at': 'Wed Mar 01 13:57:18 +0000 2017...
# 836937664032956416  {'created_at': 'Wed Mar 01 13:54:23 +0000 2017...
# 836937404392992770  {'created_at': 'Wed Mar 01 13:53:21 +0000 2017...
# 836936758537273344  {'created_at': 'Wed Mar 01 13:50:47 +0000 2017...
# 836936611363344390  {'created_at': 'Wed Mar 01 13:50:12 +0000 2017...
# 836936079139753985  {'created_at': 'Wed Mar 01 13:48:05 +0000 2017...
# 836935629439025152  {'created_at': 'Wed Mar 01 13:46:18 +0000 2017...
# 836935482739044354  {'created_at': 'Wed Mar 01 13:45:43 +0000 2017...
# 836935374899306497  {'created_at': 'Wed Mar 01 13:45:17 +0000 2017...
# 836935174306721792  {'created_at': 'Wed Mar 01 13:44:29 +0000 2017...
# 836934881317801984  {'created_at': 'Wed Mar 01 13:43:19 +0000 2017...
#
#                    data_point                            time
# 836961829469347841       none  Wed Mar 01 15:30:24 +0000 2017
# 836961765250367488       none  Wed Mar 01 15:30:09 +0000 2017
# 836961655250542593       none  Wed Mar 01 15:29:43 +0000 2017
# 836961448626548740       none  Wed Mar 01 15:28:54 +0000 2017
# 836960541268557824       none  Wed Mar 01 15:25:17 +0000 2017
# 836960498536980481       none  Wed Mar 01 15:25:07 +0000 2017
# 836959473457516544       none  Wed Mar 01 15:21:03 +0000 2017
# 836959411818016768       none  Wed Mar 01 15:20:48 +0000 2017
# 836958908178542592       none  Wed Mar 01 15:18:48 +0000 2017
# 836958762594406400       none  Wed Mar 01 15:18:13 +0000 2017
# 836958759352053762       none  Wed Mar 01 15:18:12 +0000 2017
# 836958463179784192       none  Wed Mar 01 15:17:02 +0000 2017
# 836958217389268993       none  Wed Mar 01 15:16:03 +0000 2017
# 836958037378129920       none  Wed Mar 01 15:15:20 +0000 2017
# 836957700881723393       none  Wed Mar 01 15:14:00 +0000 2017
# 836956743632498688       none  Wed Mar 01 15:10:12 +0000 2017
# 836955962749534211       none  Wed Mar 01 15:07:06 +0000 2017
# 836955793886871553       none  Wed Mar 01 15:06:25 +0000 2017
# 836955376264192000       none  Wed Mar 01 15:04:46 +0000 2017
# 836955096630046720       none  Wed Mar 01 15:03:39 +0000 2017
# 836955080725168131       none  Wed Mar 01 15:03:35 +0000 2017
# 836954878287065088       none  Wed Mar 01 15:02:47 +0000 2017
# 836954762335551488       none  Wed Mar 01 15:02:19 +0000 2017
# 836954756895551488       none  Wed Mar 01 15:02:18 +0000 2017
# 836954755435941889       none  Wed Mar 01 15:02:18 +0000 2017
# 836954754433495041       none  Wed Mar 01 15:02:17 +0000 2017
# 836954622069628928       none  Wed Mar 01 15:01:46 +0000 2017
# 836953983868493824       none  Wed Mar 01 14:59:14 +0000 2017
# 836953793073860608       none  Wed Mar 01 14:58:28 +0000 2017
# 836952973246812160       none  Wed Mar 01 14:55:13 +0000 2017
# ...                       ...                             ...
# 836943112530350082       none  Wed Mar 01 14:16:02 +0000 2017
# 836942891150868485       none  Wed Mar 01 14:15:09 +0000 2017
# 836942622832930817       none  Wed Mar 01 14:14:05 +0000 2017
# 836941753009631233       none  Wed Mar 01 14:10:38 +0000 2017
# 836941694578798592       none  Wed Mar 01 14:10:24 +0000 2017
# 836941635858608133       none  Wed Mar 01 14:10:10 +0000 2017
# 836941541818040320       none  Wed Mar 01 14:09:47 +0000 2017
# 836941535300071424       none  Wed Mar 01 14:09:46 +0000 2017
# 836941522432049152       none  Wed Mar 01 14:09:43 +0000 2017
# 836941346539646980       none  Wed Mar 01 14:09:01 +0000 2017
# 836940897317089280       none  Wed Mar 01 14:07:14 +0000 2017
# 836940849799806976       none  Wed Mar 01 14:07:02 +0000 2017
# 836940274215473152       none  Wed Mar 01 14:04:45 +0000 2017
# 836939995797585920       none  Wed Mar 01 14:03:39 +0000 2017
# 836939607103004675       none  Wed Mar 01 14:02:06 +0000 2017
# 836939034383392768       none  Wed Mar 01 13:59:50 +0000 2017
# 836939022643580931       none  Wed Mar 01 13:59:47 +0000 2017
# 836938619055026176       none  Wed Mar 01 13:58:11 +0000 2017
# 836938502335954944       none  Wed Mar 01 13:57:43 +0000 2017
# 836938397843238912       none  Wed Mar 01 13:57:18 +0000 2017
# 836937664032956416       none  Wed Mar 01 13:54:23 +0000 2017
# 836937404392992770       none  Wed Mar 01 13:53:21 +0000 2017
# 836936758537273344       none  Wed Mar 01 13:50:47 +0000 2017
# 836936611363344390       none  Wed Mar 01 13:50:12 +0000 2017
# 836936079139753985       none  Wed Mar 01 13:48:05 +0000 2017
# 836935629439025152       none  Wed Mar 01 13:46:18 +0000 2017
# 836935482739044354       none  Wed Mar 01 13:45:43 +0000 2017
# 836935374899306497       none  Wed Mar 01 13:45:17 +0000 2017
# 836935174306721792       none  Wed Mar 01 13:44:29 +0000 2017
# 836934881317801984       none  Wed Mar 01 13:43:19 +0000 2017
#
# [100 rows x 9 columns]

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes
# Out:
# tweet_id      object
# lat           object
# lon           object
# content       object
# location      object
# user          object
# raw_source    object
# data_point    object
# time          object
# dtype: object

# %%
df_tweets['location'].unique()
# Out:
# array(['Indonesia', 'Sidoarjo, Jawa Timur', 'Tanah Jawa ', '',
#        'Papua, Indonesia', 'home', 'Australia', 'Los Angeles, CA',
#        '* KUTA ROCK CITY *', 'New York, NY', 'DKI Jakarta, Indonesia',
#        'Simokerto, Indonesia', 'disini, nah disitu.', 'Tangerang, Banten',
#        'Denpasar - Bali', '@-6.325379,106.79370171,803m', 'ÜT: 0.0,0.0',
#        'Jakarta ', 'Seattle, WA', 'Central Region, Singapore', 'EARTH  ',
#        'Sukabumi', 'Earth', 'Oklahoma, USA', 'Brooklyn, NY',
#        'Indonesia . pematangsiantar', 'Easther Hemisphere',
#        'Tulungagung, Indonesia', 'Bakersfield, CA', 'Ulujami, Indonesia',
#        'between drama and reality', 'palu sulawesi tengah',
#        'jakartans - cirebon', 'USA', 'Kota Tasikmalaya, West Java',
#        'earth', 'Anywhere I Wanted To Be', 'Orlando,Florida',
#        'Manhattan, NY', '+62', 'Deket colokan listrik', 'Uppsala, Sverige',
#        'Bandung - Bogor - Lampung', 'Sumatera Utara, Indonesia',
#        'di kota macet + banjir', 'DKI Jakarta, Indonesia Border', 'Mars',
#        'Somewhere only we know..', 'Bandar Lampung, Lampung',
#        'Ngalam, East Java, Indonesia'], dtype=object)

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
grouped_tweets = df_tweets.groupby('location')
count_tweets = grouped_tweets['location'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort_index()
# Out:
#                                Count
# Location
#                                   27
# * KUTA ROCK CITY *                 1
# +62                                1
# @-6.325379,106.79370171,803m       3
# Anywhere I Wanted To Be            1
# Australia                          4
# Bakersfield, CA                    1
# Bandar Lampung, Lampung            1
# Bandung - Bogor - Lampung          1
# Brooklyn, NY                       1
# Central Region, Singapore          1
# DKI Jakarta, Indonesia             4
# DKI Jakarta, Indonesia Border      1
# Deket colokan listrik              1
# Denpasar - Bali                    1
# EARTH                              1
# Earth                              2
# Easther Hemisphere                 1
# Indonesia                          5
# Indonesia . pematangsiantar        1
# Jakarta                            1
# Kota Tasikmalaya, West Java        1
# Los Angeles, CA                    1
# Manhattan, NY                      1
# Mars                               1
# New York, NY                       4
# Ngalam, East Java, Indonesia       1
# Oklahoma, USA                      1
# Orlando,Florida                    1
# Papua, Indonesia                   1
# Seattle, WA                        2
# Sidoarjo, Jawa Timur               1
# Simokerto, Indonesia               1
# Somewhere only we know..           1
# Sukabumi                           1
# Sumatera Utara, Indonesia          1
# Tanah Jawa                         1
# Tangerang, Banten                  1
# Tulungagung, Indonesia             1
# USA                                1
# Ulujami, Indonesia                 1
# Uppsala, Sverige                   1
# between drama and reality          1
# di kota macet + banjir             1
# disini, nah disitu.                1
# earth                              4
# home                               1
# jakartans - cirebon                3
# palu sulawesi tengah               1
# ÜT: 0.0,0.0                        3

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#697dc6","#5faf4c","#7969de","#b5b246",
          "#cc54bc","#4bad89","#d84577","#4eacd7",
          "#cf4e33","#894ea8","#cf8c42","#d58cc9",
          "#737632","#9f4b75","#c36960"]

# Create a pie chart
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location
# Out:
# Empty DataFrame
# Columns: [tweet_id, lat, lon, content, location, user, raw_source, data_point, time]
# Index: []

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-1dff57db92fa> in <module>()
#       1 # Use a scatter plot to make a quick visualization of the data points
#       2 # NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
# ----> 3 plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
#       4 plt.show()
#
# /Users/smt/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# /Users/smt/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/smt/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3993         maskargs = x, y, s, c, colors, edgecolors, linewidths
#    3994         x, y, s, c, colors, edgecolors, linewidths =\
# -> 3995             cbook.delete_masked_points(*maskargs)
#    3996
#    3997         scales = s   # Renamed for readability below.
#
# /Users/smt/anaconda/lib/python3.6/site-packages/matplotlib/cbook.py in delete_masked_points(*args)
#    1834         return ()
#    1835     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1836         raise ValueError("First argument must be a sequence")
#    1837     nrecs = len(args[0])
#    1838     margs = []
#
# ValueError: First argument must be a sequence

# %% [markdown]
# ### 8. Clean the Data
#
# **Clean the Locations** - You saw above that we had a bunch of locations that were very similar. Here, we could use [replace](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html). For example, we could replace all the variations of **York, PA** with a singular string using something like the following:

# %%
# List of variations of York
variations_of_york = ['York, PA','York PA','York, Pennsylvania','York, Pa','41 W Market Street York, Pa','york P.a. ','York, Pa.']

df_tweets['location'].replace(variations_of_york, 'York, PA')

# %% [markdown]
# **Remove Duplicates** - Make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe use [drop_duplicates](http://chrisalbon.com/python/pandas_delete_duplicates.html)

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 20 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.
